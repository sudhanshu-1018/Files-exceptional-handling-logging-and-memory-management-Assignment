# %% [markdown]
# ###  Theoretical

# %%
'''
1. What is the difference between interpreted and compiled languages?
Compiled languages translate the entire program before execution, while interpreted languages execute code line by line at runtime.

2. What is exception handling in Python?
Exception handling in Python is a way to manage runtime errors so the program continues running smoothly instead of crashing.

3. What is the purpose of the finally block in exception handling?
The finally block is used to execute cleanup code and it runs whether an exception occurs or not.

4. What is logging in Python?
Logging in Python records program activities such as errors and warnings to help with debugging and monitoring.

5. What is the significance of the __del__ method in Python?
The __del__ method is called when an object is destroyed and is mainly used to release resources.

6. What is the difference between import and from import in Python?
The import statement loads the entire module, while from import brings specific items directly into the current program.

7. How can you handle multiple exceptions in Python?
Multiple exceptions can be handled by using multiple except blocks or grouping exceptions together.

8. What is the purpose of the with statement when handling files in Python?
The with statement automatically closes the file after its operations are completed.

9. What is the difference between multithreading and multiprocessing?
Multithreading runs multiple threads in one process sharing memory, while multiprocessing runs separate processes with independent memory.

10. What are the advantages of using logging in a program?
Logging helps in debugging, tracking errors, and maintaining a history of program execution.

11. What is memory management in Python?
Memory management in Python refers to automatic allocation and deallocation of memory by the interpreter.

12. What are the basic steps involved in exception handling in Python?
The basic steps include using try for risky code, except for handling errors, else for successful execution, and finally for cleanup.

13. Why is memory management important in Python?
Memory management is important because it prevents memory leaks and improves program performance.

14. What is the role of try and except in exception handling?
The try block contains code that may cause errors, and the except block handles those errors.

15. How does Python's garbage collection system work?
Python removes unused objects automatically using reference counting and garbage collection.

16. What is the purpose of the else block in exception handling?
The else block runs only when no exception occurs in the try block.

17. What are the common logging levels in Python?
The common logging levels are DEBUG, INFO, WARNING, ERROR, and CRITICAL.

18. What is the difference between os.fork() and multiprocessing in Python?
os.fork() duplicates the current process and works mainly on Unix systems, while multiprocessing provides a portable way to create multiple processes.

19. What is the importance of closing a file in Python?
Closing a file ensures data is saved properly and system resources are freed.

20. What is the difference between file.read() and file.readline() in Python?
file.read() reads the entire file, while file.readline() reads one line at a time.

21. What is the logging module in Python used for?
The logging module is used to capture program messages and errors.

22. What is the os module in Python used for in file handling?
The os module is used for managing files and directories such as creating, deleting, and checking paths.

23. What are the challenges associated with memory management in Python?
Challenges include circular references, handling large objects, and performance overhead.

24. How do you raise an exception manually in Python?
An exception can be raised manually using the raise keyword.

25. Why is it important to use multithreading in certain applications?
Multithreading improves responsiveness and allows multiple tasks to run at the same time.
'''

# %% [markdown]
# ### Practicle

# %% [markdown]
# 1. How can you open a file for writing in Python and write a string to it?

# %%
with open("sample.txt","w") as f:
    f.write("Hello from Python")

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line.

# %%
with open("sample.txt","r") as f:
    for line in f:
        print(line.strip())

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    open("nofile.txt","r")
except FileNotFoundError:
    print("File not found")

# %% [markdown]
# 4. Write a Python script that reads from one file and writes its content to another file.

# %%
with open("sample.txt","r") as f1, open("copy.txt","w") as f2:
    f2.write(f1.read())

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python?

# %%
try:
    x = 10/0
except ZeroDivisionError:
    print("Division by zero handled")

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging
logging.basicConfig(filename="error.log", level=logging.ERROR)
try:
    5/0
except ZeroDivisionError:
    logging.error("Division by zero occurred")

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Info message")
logging.warning("Warning message")
logging.error("Error message")

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling.

# %%
try:
    open("missing.txt","r")
except IOError:
    print("Cannot open file")

# %% [markdown]
# 9. How can you read a file line by line and store its content in a list in Python?

# %%
lines=[]
with open("sample.txt","r") as f:
    for l in f:
        lines.append(l.strip())
print(lines)

# %% [markdown]
# 10. How can you append data to an existing file in Python?

# %%
with open("sample.txt","a") as f:
    f.write("\nAppended text")

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

# %%
data={"a":1}
try:
    print(data["b"])
except KeyError:
    print("Key not found")

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
try:
    int("abc")
except ValueError:
    print("ValueError")
except TypeError:
    print("TypeError")

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?

# %%
import os
if os.path.exists("sample.txt"):
    print("File exists")

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages.

# %%
import logging
logging.basicConfig(filename="app.log", level=logging.INFO)
logging.info("Program started")
try:
    1/0
except:
    logging.error("Error occurred")

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
with open("sample.txt","r") as f:
    content=f.read()
    if content=="":
        print("File empty")
    else:
        print(content)

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
import tracemalloc
tracemalloc.start()
a=[i for i in range(10000)]
print(tracemalloc.get_traced_memory())
tracemalloc.stop()

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
nums=[1,2,3,4,5]
with open("numbers.txt","w") as f:
    for n in nums:
        f.write(str(n)+"\n")

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler
logger=logging.getLogger()
handler=RotatingFileHandler("rotate.log",maxBytes=1024*1024,backupCount=2)
logger.addHandler(handler)
logger.setLevel(logging.INFO)
logger.info("Rotating log test")

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block.

# %%
try:
    lst=[1,2]
    print(lst[5])
    d={"a":1}
    print(d["b"])
except (IndexError,KeyError):
    print("Index or Key error handled")

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python?

# %%
with open("sample.txt","r") as f:
    print(f.read())

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
word="Python"
count=0
with open("sample.txt","r") as f:
    for line in f:
        count+=line.count(word)
print(count)

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents?

# %%
import os
if os.path.getsize("sample.txt")==0:
    print("Empty file")
else:
    print("Not empty")

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging
logging.basicConfig(filename="fileerror.log",level=logging.ERROR)
try:
    open("abc.txt")
except Exception as e:
    logging.error(e)
